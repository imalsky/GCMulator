# %%
import numpy as np
import matplotlib.pyplot as plt

import json
import glob

import random

plt.style.use('/Users/imalsky/science.mplstyle')

# %%
files = glob.glob('generated_profiles_json/prof_*.json')

print(files)
# Out:
# ['generated_profiles_json/prof_21.json', 'generated_profiles_json/prof_37.json', 'generated_profiles_json/prof_40.json', 'generated_profiles_json/prof_17.json', 'generated_profiles_json/prof_7.json', 'generated_profiles_json/prof_6.json', 'generated_profiles_json/prof_16.json', 'generated_profiles_json/prof_41.json', 'generated_profiles_json/prof_36.json', 'generated_profiles_json/prof_20.json', 'generated_profiles_json/prof_46.json', 'generated_profiles_json/prof_11.json', 'generated_profiles_json/prof_1.json', 'generated_profiles_json/prof_50.json', 'generated_profiles_json/prof_27.json', 'generated_profiles_json/prof_31.json', 'generated_profiles_json/prof_30.json', 'generated_profiles_json/prof_26.json', 'generated_profiles_json/prof_10.json', 'generated_profiles_json/prof_47.json', 'generated_profiles_json/prof_3.json', 'generated_profiles_json/prof_13.json', 'generated_profiles_json/prof_44.json', 'generated_profiles_json/prof_29.json', 'generated_profiles_json/prof_48.json', '
# ...

# %%
for i in range(10):
    index = random.randint(1, len(files) - 1)
    with open(files[index], 'r') as file:
        data = json.load(file)
        plt.plot(data['temperature_k'], data['pressure_bar'])
plt.yscale('log')
plt.ylim(1e2, 1e-5)
plt.xlim(0, 4000)
# Out:
# (0.0, 4000.0)
